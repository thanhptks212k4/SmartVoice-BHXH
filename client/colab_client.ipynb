# %% [markdown]
# # Voice AI Client — Whisper STT trên Colab
# Chạy từng cell theo thứ tự.

# %%
# Cell 1: Cài thư viện
# !pip install -q openai-whisper websocket-client requests numpy scipy

# %%
# Cell 2: Config — chỉnh ở đây
BASE_URL   = "http://YOUR_SERVER_IP:3000"   # <-- đổi IP server
WS_URL     = "ws://YOUR_SERVER_IP:3000"     # <-- đổi IP server
USER_DATA  = {"username": "BHXH", "password": "123456"}
VOICE      = "nuhanoi"
WHISPER_MODEL = "small"   # tiny / base / small / medium

# %%
# Cell 3: Load Whisper
import whisper
print(f"Loading Whisper model: {WHISPER_MODEL}...")
whisper_model = whisper.load_model(WHISPER_MODEL)
print("Whisper ready!")
